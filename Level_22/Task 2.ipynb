# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
def create_model():
    model = Sequential([
        Dense(128, activation='relu', input_shape=(784,)),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
batch_sizes = [len(x_train), 1, 32]  
history_dict = {}

for batch_size in batch_sizes:
    print(f"Training with batch size: {batch_size}")
    model = create_model()
    history = model.fit(x_train, y_train,
                        epochs=10,
                        batch_size=batch_size,
                        validation_data=(x_test, y_test),
                        verbose=1)
    history_dict[batch_size] = history
# Out:
# Training with batch size: 60000
# c:\Users\loalo\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1204 - loss: 2.4075 - val_accuracy: 0.1728 - val_loss: 2.2408
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.1709 - loss: 2.2419 - val_accuracy: 0.2841 - val_loss: 2.0947
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step - accuracy: 0.2809 - loss: 2.0976 - val_accuracy: 0.4069 - val_loss: 1.9607
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - accuracy: 0.4074 - loss: 1.9651 - val_accuracy: 0.5158 - val_loss: 1.8342
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step - accuracy: 0.5166 - loss: 1.8403 - val_accuracy: 0.5912 - val_loss: 1.7136
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.5922 - loss: 1.7214 - val_accuracy: 0.6447 - val_loss: 1.5992
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step - accuracy: 0.6419 - loss: 1.6085 - val_accuracy: 0.6812 - val_loss: 1.4915
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - accuracy: 0.6746 - loss: 1.5024 - val_accuracy: 0.7054 - val_loss: 1.3912
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6994 - loss: 1.4036 - val_accuracy: 0.7240 - val_loss: 1.2986
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.7191 - loss: 1.3125 - val_accuracy: 0.7432 - val_loss: 1.2131
# Training with batch size: 1
# Epoch 1/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 263s 4ms/step - accuracy: 0.9053 - loss: 0.3129 - val_accuracy: 0.9553 - val_loss: 0.1621
# Epoch 2/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 292s 5ms/step - accuracy: 0.9674 - loss: 0.1233 - val_accuracy: 0.9701 - val_loss: 0.1241
# Epoch 3/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 251s 4ms/step - accuracy: 0.9738 - loss: 0.1035 - val_accuracy: 0.9711 - val_loss: 0.1514
# Epoch 4/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 233s 4ms/step - accuracy: 0.9791 - loss: 0.0871 - val_accuracy: 0.9693 - val_loss: 0.1697
# Epoch 5/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 212s 4ms/step - accuracy: 0.9820 - loss: 0.0764 - val_accuracy: 0.9715 - val_loss: 0.1755
# Epoch 6/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 210s 3ms/step - accuracy: 0.9836 - loss: 0.0724 - val_accuracy: 0.9695 - val_loss: 0.2180
# Epoch 7/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 205s 3ms/step - accuracy: 0.9850 - loss: 0.0688 - val_accuracy: 0.9739 - val_loss: 0.2020
# Epoch 8/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 206s 3ms/step - accuracy: 0.9878 - loss: 0.0577 - val_accuracy: 0.9711 - val_loss: 0.2458
# Epoch 9/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 205s 3ms/step - accuracy: 0.9887 - loss: 0.0521 - val_accuracy: 0.9697 - val_loss: 0.3167
# Epoch 10/10
# 60000/60000 ━━━━━━━━━━━━━━━━━━━━ 247s 3ms/step - accuracy: 0.9887 - loss: 0.0530 - val_accuracy: 0.9727 - val_loss: 0.2766
# Training with batch size: 32
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8804 - loss: 0.4279 - val_accuracy: 0.9575 - val_loss: 0.1444
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9639 - loss: 0.1231 - val_accuracy: 0.9680 - val_loss: 0.1052
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9766 - loss: 0.0785 - val_accuracy: 0.9739 - val_loss: 0.0836
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9830 - loss: 0.0572 - val_accuracy: 0.9755 - val_loss: 0.0802
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9871 - loss: 0.0443 - val_accuracy: 0.9747 - val_loss: 0.0836
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9897 - loss: 0.0330 - val_accuracy: 0.9770 - val_loss: 0.0797
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9914 - loss: 0.0277 - val_accuracy: 0.9755 - val_loss: 0.0851
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9939 - loss: 0.0209 - val_accuracy: 0.9782 - val_loss: 0.0807
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9948 - loss: 0.0171 - val_accuracy: 0.9738 - val_loss: 0.0930
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9949 - loss: 0.0154 - val_accuracy: 0.9773 - val_loss: 0.0869

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
for batch_size, history in history_dict.items():
    plt.plot(history.history['accuracy'], label=f'Batch Size {batch_size}')
plt.title('Training Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
plt.subplot(1, 2, 2)
for batch_size, history in history_dict.items():
    plt.plot(history.history['val_loss'], label=f'Batch Size {batch_size}')
plt.title('Validation Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
