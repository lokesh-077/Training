# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.binomial(n=10,p=0.5,size=1000)
plt.hist(data,bins=range(12),density=True)
plt.title("Binomial Distribution Simulation")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.show()
mean_value = data.mean()
print(f"Mean of the simulated data: {mean_value:.2f}")
print("Matches binomial expectation (n × p = 5).")
# Out:
# Mean of the simulated data: 5.00
# Matches binomial expectation (n × p = 5).
