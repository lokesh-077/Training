# %%
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
X,y=make_moons(n_samples=100,noise=0.1,random_state=42)

model=StandardScaler()
X_scaled=model.fit_transform(X)

svc_linear = SVC(kernel='linear')
svc_linear.fit(X_scaled, y)
svc_rbf = SVC(kernel='rbf')
svc_rbf.fit(X_scaled, y)

X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.1,random_state=42)
y_pred_linear=svc_linear.predict(X_test)
y_pred_rbf=svc_rbf.predict(X_test)
accuracy_linear=accuracy_score(y_test,y_pred_linear)
accuracy_rbf=accuracy_score(y_test,y_pred_rbf)

plt.plot(X_scaled)
plt.title("SVM with keral")
plt.show

print(f"Accuracy of SVC with Linear Kernel: {accuracy_linear}")
print(f"Accuracy of SVC with RBF Kernel: {accuracy_rbf}")
if accuracy_linear > accuracy_rbf:
    print("The linear kernel performed better, indicating the problem is likely linearly separable.")
else:
    print("The RBF kernel performed better, suggesting the problem might require a non-linear decision boundary.")
# Out:
# Accuracy of SVC with Linear Kernel: 1.0
# Accuracy of SVC with RBF Kernel: 1.0
# The RBF kernel performed better, suggesting the problem might require a non-linear decision boundary.
