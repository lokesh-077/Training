# %% [markdown]
#  House Price EDA

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\loalo\\Downloads\\housing.csv')
df
# Out:
#             price          area      bedrooms     bathrooms       stories  \
# 0        13300000          7420             4             2             3
# 1        12250000          8960             4             4             4
# 2        12250000          9960             3             2             2
# 3        12215000          7500             4             2             2
# 4        11410000          7420             4             1             2
# ..            ...           ...           ...           ...           ...
# 541  -66626827.59   -43079.0613  -13.51122058   -15.1863711  -12.11193213
# 542  -66776741.38  -43178.39354  -13.54460865  -15.22003284  -12.14012042
# 543  -66926655.17  -43277.72578  -13.57799672  -15.25369458   -12.1683087
# 544  -67076568.97  -43377.05802  -13.61138478  -15.28735632  -12.19649699
# 545  -67226482.76  -43476.39026  -13.64477285  -15.32101806  -12.22468528
#
#     mainroad guestroom basement hotwaterheating airconditioning  parking  \
# ...

# %%
stats = df.describe()
stats
# Out:
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000
