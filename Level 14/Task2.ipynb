# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

df = pd.read_csv("D:/winequality.csv")

X = df.drop('quality', axis=1)
y = df['quality']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
print("Shape of the data after PCA:", X_pca.shape)
print("Explained variance ratio:", pca.explained_variance_ratio_)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Wine Quality Dataset')
plt.colorbar(label='Wine Quality')
plt.show()
explained_variance = pca.explained_variance_ratio_.sum()
print("Explained variance ratio (sum):", explained_variance)
# Out:
# Shape of the data after PCA: (1599, 2)
# Explained variance ratio: [0.28173931 0.1750827 ]
# Explained variance ratio (sum): 0.45682201184235877
