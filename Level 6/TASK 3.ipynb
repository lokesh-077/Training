# %%
# !pip install scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
 
df = pd.read_csv( "C:\\Users\\loalo\\Downloads\\Employee Attrition.csv" )
df
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
print("Dataset Overview:")
print(df.head())
# Out:
# Dataset Overview:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0     1.0                0.38             0.53             2.0
# 1     2.0                0.80             0.86             5.0
# 2     3.0                0.11             0.88             7.0
# 3     4.0                0.72             0.87             5.0
# 4     5.0                0.37             0.52             2.0
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                 157.0                 3.0            0.0
# 1                 262.0                 6.0            0.0
# 2                 272.0                 4.0            0.0
# 3                 223.0                 5.0            0.0
# 4                 159.0                 3.0            0.0
#
#    promotion_last_5years   dept  salary
# 0                    0.0  sales     low
# 1                    0.0  sales  medium
# 2                    0.0  sales  medium
# 3                    0.0  sales     low
# ...

# %%
df_cleaned = df.dropna(subset=["dept"])
sample_df, _ = train_test_split(df_cleaned, test_size=0.7, stratify=df_cleaned["dept"], random_state=42)
print("\nSampled Data Distribution:\n", sample_df["dept"].value_counts(normalize=True))
print("\nOriginal Data Distribution:\n", df_cleaned["dept"].value_counts(normalize=True))
# Out:
# Sampled Data Distribution:
#  dept
# sales          0.276061
# technical      0.181374
# support        0.148700
# IT             0.081796
# product_mng    0.060013
# marketing      0.057124
# RandD          0.052456
# accounting     0.051122
# hr             0.049344
# management     0.042009
# Name: proportion, dtype: float64
#
# Original Data Distribution:
#  dept
# sales          0.276018
# technical      0.181345
# support        0.148610
# IT             0.081805
# product_mng    0.060137
# marketing      0.057204
# RandD          0.052470
# accounting     0.051137
# hr             0.049270
# management     0.042003
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
df["dept"].value_counts().plot(kind="bar", color="blue", alpha=0.7)
plt.title("Original Department Distribution")
plt.xlabel("Department")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 2, 2)
sample_df["dept"].value_counts().plot(kind="bar", color="green", alpha=0.7)
plt.title("Sampled Department Distribution (30%)")
plt.xlabel("Dept")
plt.ylabel("Count")

plt.tight_layout()
plt.show()
